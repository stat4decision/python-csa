# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
from pandas import DataFrame, Series

# %% [markdown]
# Définir un objet Series comprenant la population de 5 pays puis afficher les pays ayant une population > 50’000’000.

# %%
ser1=Series([70,8,300,40],index=["France","Suisse","USA", "Espagne"])

ser2=Series({"France":70, "Suisse":8,"USA":300, "Espagne":40})
ser2
# Out:
# Espagne     40
# France      70
# Suisse       8
# USA        300
# dtype: int64

# %%
ser1[ser1>50]
# Out:
# France     70
# USA       300
# dtype: int64

# %% [markdown]
# Ajoutez un nom à la séries et à la liste d'index

# %%
ser1.name="Population"
ser1.index.name="Pays"
ser1
# Out:
# Pays
# France      70
# Suisse       8
# USA        300
# Espagne     40
# Name: Population, dtype: int64

# %% [markdown]
# Construire un dictionnaire avec des produits et des prix puis afficher le DataFrame obtenu en transformant ce dictionnaire

# %%
dico1={"produits":["P1","P2","P3","P4"],"prix":[40,30,60,20]}
frame1=DataFrame(dico1)

frame2=DataFrame([40,30,60,20],index=["P1","P2","P3","P4"],columns=["Prix"])

frame2
# Out:
#     Prix
# P1    40
# P2    30
# P3    60
# P4    20

# %% [markdown]
# Récupérez les données de Wikipédia sur les résultats de NBA et obtenir les statistiques descriptives pour les variables quantitatives.

# %%
import webbrowser
url='https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records'
webbrowser.open(url)
# Out:
# True

# %%
#on récupère les données du presse-papier
frameNBA=pd.read_clipboard()

# %%
#on affiche les informations sur le dataframe
frameNBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
# Rank                30 non-null int64
# Team                30 non-null object
# Won                 30 non-null object
# Lost                30 non-null object
# Pct.                30 non-null float64
# First NBA Season    30 non-null object
# Total Games         30 non-null object
# Division            30 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.0+ KB

# %%
frameNBA
# Out:
#     Rank                    Team     Won    Lost   Pct. First NBA Season  \
# 0      1       San Antonio Spurs  2006.0  1226.0  0.621          1976–77
# 1      2      Los Angeles Lakers  3235.0  2134.0  0.603          1948–49
# 2      3          Boston Celtics  3221.0  2257.0  0.588          1946–47
# 3      4            Phoenix Suns  2122.0  1766.0  0.546          1968–69
# 4      5   Oklahoma City Thunder  2139.0  1831.0  0.539          1967–68
# 5      6  Portland Trail Blazers  1991.0  1733.0  0.535          1970–71
# 6      7               Utah Jazz  1815.0  1581.0  0.534          1974–75
# 7      8           Chicago Bulls  2115.0  1936.0  0.522          1966–67
# 8      9              Miami Heat  1170.0  1078.0  0.520          1988–89
# 9     10         Houston Rockets  2052.0  1918.0  0.517          1967–68
# 10    11      Philadelphia 76ers  2726.0  2578.0  0.514          1949–50
# 11    12        Dallas Mavericks  1482.0  1422.0  0.510          1980–81
# ...

# %%
#créer un second data frame
frameNBA2=frameNBA[frameNBA.columns[1:4]]

# %%
#on modifie les données mal importées
listVar=["Won","Lost","Total Games"]
for label in listVar:
    frameNBA[label]=frameNBA[label].str.replace(",","")
    frameNBA[label]=frameNBA[label].astype(float)

# %%
#on affiche les stats descriptives
frameNBA.describe(include="all")
# Out:
#              Rank          Team          Won         Lost       Pct.  \
# count   30.000000            30    30.000000    30.000000  30.000000
# unique        NaN            30          NaN          NaN        NaN
# top           NaN  Phoenix Suns          NaN          NaN        NaN
# freq          NaN             1          NaN          NaN        NaN
# mean    15.500000           NaN  1852.966667  1843.833333   0.494000
# std      8.803408           NaN   737.296342   632.949804   0.056163
# min      1.000000           NaN   528.000000   604.000000   0.391000
# 25%      8.250000           NaN  1387.250000  1344.750000   0.460250
# 50%     15.500000           NaN  1987.000000  1851.500000   0.495000
# 75%     22.750000           NaN  2382.750000  2256.500000   0.521500
# max     30.000000           NaN  3235.000000  2905.000000   0.621000
#
#        First NBA Season  Total Games  Division
# count                30    30.000000        30
# ...

# %% [markdown]
# Extraire les équipes ayant gagné plus de 2000 matchs

# %%
frameNBA[frameNBA["Won"]>2000][["Team","Pct."]]
# Out:
#                      Team   Pct.
# 0       San Antonio Spurs  0.621
# 1      Los Angeles Lakers  0.603
# 2          Boston Celtics  0.588
# 3            Phoenix Suns  0.546
# 4   Oklahoma City Thunder  0.539
# 7           Chicago Bulls  0.522
# 9         Houston Rockets  0.517
# 10     Philadelphia 76ers  0.514
# 13          Atlanta Hawks  0.499
# 15        New York Knicks  0.493
# 17        Detroit Pistons  0.487
# 19  Golden State Warriors  0.473
# 22       Sacramento Kings  0.459
# 23     Washington Wizards  0.450

# %% [markdown]
# Construire deux frames avec quelques colonnes et lignes en commun puis combinez-les.

# %%
frame2=DataFrame(np.random.randn(6).reshape(2,3),index=["obs1","obs2"],columns=["X1","X2","X3"])
frame3=DataFrame(np.random.randn(6).reshape(2,3),index=["obs1","obs3"],columns=["X1","X2","X4"])

# %%
frame2+frame3
# Out:
#             X1        X2  X3  X4
# obs1 -2.871515  0.217699 NaN NaN
# obs2       NaN       NaN NaN NaN
# obs3       NaN       NaN NaN NaN

# %%
#on somme les valeurs communes et on remplace par 0 les valeurs manquantes
frame2.add(frame3,fill_value=0).fillna(0)
# Out:
#             X1        X2        X3        X4
# obs1 -2.871515  0.217699  1.662697  0.040622
# obs2 -0.585910  0.737165 -0.192154  0.000000
# obs3  0.280586  1.987784  0.000000  1.315717

# %% [markdown]
# Trier les données NBA en fonction de la variable Won puis Division / Won

# %%
frameNBA.sort_values("Won",inplace=True)
frameNBA.sort_values(["Division","Won"],ascending=[True,False],inplace=True)
frameNBA
# Out:
#     Rank                    Team     Won    Lost   Pct. First NBA Season  \
# 2      3          Boston Celtics  3221.0  2257.0  0.588          1946–47
# 10    11      Philadelphia 76ers  2726.0  2578.0  0.514          1949–50
# 15    16         New York Knicks  2701.0  2774.0  0.493          1946–47
# 26    27           Brooklyn Nets  1360.0  1872.0  0.421          1976–77
# 25    26         Toronto Raptors   734.0   940.0  0.438          1995–96
# 17    18         Detroit Pistons  2616.0  2752.0  0.487          1948–49
# 7      8           Chicago Bulls  2115.0  1936.0  0.522          1966–67
# 12    13         Milwaukee Bucks  1983.0  1905.0  0.510          1968–69
# 21    22     Cleveland Cavaliers  1728.0  1996.0  0.464          1970–71
# 14    15          Indiana Pacers  1606.0  1625.0  0.497          1976–77
# 4      5   Oklahoma City Thunder  2139.0  1831.0  0.539          1967–68
# 5      6  Portland Trail Blazers  1991.0  1733.0  0.535          1970–71
# ...

# %% [markdown]
# Obtenir les corrélations pour les données NBA.

# %%
frameNBA.corr()
# Out:
#                  Rank       Won      Lost      Pct.  Total Games
# Rank         1.000000 -0.568841 -0.065044 -0.969359    -0.351810
# Won         -0.568841  1.000000  0.824618  0.600164     0.961872
# Lost        -0.065044  0.824618  1.000000  0.074978     0.947893
# Pct.        -0.969359  0.600164  0.074978  1.000000     0.374254
# Total Games -0.351810  0.961872  0.947893  0.374254     1.000000

# %% [markdown]
# ## Importation de données

# %% [markdown]
# Importez le fichier demo_ventes.csv depuis Python dans frameVentes.

# %%
frameVentes=pd.read_csv("..\Formation python csa\demo_ventes.csv",sep=";")

# %% [markdown]
# Récupérez automatiquement les données d'un site web (BeautifulSoup et html5lib doivent être dans votre environnement)

# %%
dataBank=pd.io.html.read_html("https://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
frameBank=dataBank[0]

# %%
dataNBA=pd.io.html.read_html("https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records")

# %%
dataNBA[3]
# Out:
#        0                       1    2     3     4                        5  \
# 0   Rank                    Team  Won  Lost  Pct.  Last playoff appearance
# 1      1      Los Angeles Lakers  438   296  .597                     2013
# 2      2          Boston Celtics  346   261  .570                     2016
# 3      3              Miami Heat  123    96  .562                     2016
# 4      4       San Antonio Spurs  210   165  .560                     2016
# 5      5           Chicago Bulls  184   154  .544                     2015
# 6      6     Cleveland Cavaliers  100    89  .529                     2016
# 7      7         Detroit Pistons  188   178  .514                     2016
# 8      8      Philadelphia 76ers  216   205  .513                     2012
# 9      9   Oklahoma City Thunder  157   151  .510                     2016
# 10    10          Indiana Pacers  112   110  .505                     2016
# ...

# %% [markdown]
# Importez un fichier Excel depuis python. On utilisera excel-data.xlsx

# %%
#1ere méthode
frameExcel=pd.read_excel("excel-data.xlsx")
#2ème méthode
fichierExcel=pd.ExcelFile("excel-data.xlsx")

# %%
fichierExcel.sheet_names
name.find('sheet1')
# Out:
# 0

# %%
#pour créer des DataFrame indéxés dynamiquement, on préfère les stocker dans un dictionnaire (on évite d'indicer 
#les dataframes en python)
df_dict={}
for name in fichierExcel.sheet_names:
    if name.find('eet'):
        df_dict[name]=fichierExcel.parse(name)
    print(name)
# Out:
# sheet1

# %%
df_dict["sheet1"]
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %% [markdown]
# Importation de bases SQL

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///salaries.sqlite')

# %%
engine.table_names()
# Out:
# ['Salaries']

# %%
frameSalaries=pd.read_sql_query("SELECT * from Salaries",engine)

# %%
frameSalaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411           0   400184           567595.43         567595.43  2011
# 1  155966      245132   137811           538909.28         538909.28  2011
# 2  212739      106088  16452.6           335279.91         335279.91  2011
# 3   77916     56120.7   198307           332343.61         332343.61  2011
# 4  134402        9737   182235           326373.19         326373.19  2011
#
#   Notes         Agency Status
# 0        San Francisco
# ...

# %%
frameSalaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148654 non-null object
# OvertimePay         148654 non-null object
# OtherPay            148654 non-null object
# Benefits            148654 non-null object
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               148654 non-null object
# Agency              148654 non-null object
# Status              148654 non-null object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 14.7+ MB

# %% [markdown]
# Joindre les deux dataframes de ventes en utilisant l’id.

# %%
frameMerge=pd.merge(frameExcel,frameVentes,how="inner",on="account")

# %%
frameMerge
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
frameSalaries.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year
# count  148654.000000  148654.000000     148654.000000  148654.000000
# mean    74327.500000   74768.321972      93692.554811    2012.522643
# std     42912.857795   50517.005274      62793.533483       1.117538
# min         1.000000    -618.130000       -618.130000    2011.000000
# 25%     37164.250000   36168.995000      44065.650000    2012.000000
# 50%     74327.500000   71426.610000      92404.090000    2013.000000
# 75%    111490.750000  105839.135000     132876.450000    2014.000000
# max    148654.000000  567595.430000     567595.430000    2014.000000

# %% [markdown]
# On veut discrétiser la variable TotalPay

# %%
frameSalaries["salaires disc"]=pd.cut(frameSalaries.TotalPay,bins=[frameSalaries.TotalPay.min(), 10000
                                                                  ,50000,100000, frameSalaries.TotalPay.max()])
frameSalaries["salaires disc"].value_counts()
# Out:
# (50000, 100000]        60795
# (100000, 567595.43]    41967
# (10000, 50000]         27254
# (-618.13, 10000]       18637
# Name: salaires disc, dtype: int64

# %%
frameSalaries.salaires_disc_2=pd.qcut(frameSalaries.TotalPay,5)

frameSalaries.salaires_disc_2.value_counts()

# %% [markdown]
# Utilisez le groupby pour diviser les données en utilisant la division

# %%
grouperNBA=frameNBA.groupby("Division")

# %%
grouperNBA.agg(["mean","median"])
# Out:
#            Rank            Won            Lost            Pct.         \
#            mean median    mean  median    mean  median    mean median
# Division
# Atlantic   16.6     16  1903.6  2701.0  2084.2  2257.0  0.4908  0.493
# Central    15.2     15  2009.6  1983.0  2042.8  1936.0  0.4960  0.497
# Northwest  13.4      7  1671.0  1815.0  1626.6  1669.0  0.4966  0.534
# Pacific    15.6     20  1909.8  2122.0  2388.8  2255.0  0.4950  0.473
# Southeast  17.8     17   872.8   916.0  1690.6  1168.0  0.4798  0.490
# Southwest  14.4     12  1352.4  1482.0  1230.0  1226.0  0.5058  0.510
#
#           Total Games
#                  mean  median
# Division
# Atlantic       4232.6  5304.0
# Central        4052.4  3888.0
# Northwest      2583.0  3232.0
# Pacific        4764.8  5369.0
# Southeast      3251.0  2248.0
# Southwest      1867.8  1674.0

# %% [markdown]
# Créez un objet Series et ajoutez des dates partant du 3 décembre 2016 par jour jusqu’à aujourd’hui.

# %%
serDates=Series(np.random.randn(100),index=pd.date_range(start="2016-12-03",periods=100,freq='2 D'))

# %%
frameDates=DataFrame(["25-03-2016","26-03-2016"],columns=["date"])
